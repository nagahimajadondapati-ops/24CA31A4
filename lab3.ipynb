# %% [markdown]
# ### Exercise 3: Text Representation Techniques

# %% [markdown]
# ### Aim:
# To implement text representation techniques by generating One‑Hot Encoding, Bag of Words (BoW), and Word Cloud for a given text corpus to prepare textual data for Natural Language Processing (NLP) and machine learning applications.

# %% [markdown]
# ### Objectives
# After completing this experiment, students will be able to:
#
# Create a vocabulary from a given text corpus.
#
# Represent unique words using One‑Hot Encoding.
#
# Construct a Bag of Words (BoW) model by computing word frequencies.
#
# Generate a Document‑Term Matrix (DTM) from the corpus.
#
# Visualize word frequencies using a Word Cloud.
#
#  ### Expected Output:
#
# ### 1.Vocabulary:
# A list of all unique words in the corpus.
# Example: ['I', 'love', 'NLP', 'Python', 'is', 'fun']
#
# ### 2.One-Hot Encoding:
# Each unique word is represented by a binary vector.
# Example: Python → [0, 0, 0, 1, 0, 0]
#
# ### 3.Bag of Words (BoW):
# Shows how many times each word occurs in the corpus.
#
# ### 4.Document-Term Matrix (DTM):
# A matrix where:
# Rows = Documents
# Columns = Vocabulary words
# Values = Word frequencies
# Example:
# Document	I	love	NLP	Python	is	fun
# D1	1	1	1	0	0	0
# D2	1	1	0	1	0	0
# D3	0	0	1	0	1	1
#
# ### 5.Word Cloud:
# A visual image where frequently occurring words appear larger.
# In the given corpus, “I”, “love”, and “NLP” will appear relatively large because they occur more frequently.

# %% [markdown]
# ### Pre-Lab
# D1: I love NLP
# D2: I love Python
# D3: NLP is fun
#
# ### 1.  Identify all the unique words (vocabulary)?
# A. Vocabulary: I, love, NLP, Python, is, fun.
#
#
#
# ### 2. What is the size of the vocabulary?
# A. Vocabulary size: 6.
# There are 6 unique words: I, love, NLP, Python, is, fun.
#
#
# ### 3. Write the One-Hot Encoding vectornfor the word "Python"
# A. One-Hot Encoding for “Python”: [0, 0, 0, 1, 0, 0]
# Here, 1 represents the position of “Python” in the vocabulary.
#
#
# ### 4. Count how many times the word "love" appears in each document?
# A.Love count: D1 = 1, D2 = 1, D3 = 0.
# So, “love” appears 2 times in total.
#
#
# ### 5. Predict which word will appear largest in the Word Cloud and explain why?
# A. Largest words: “I”, “love”, and “NLP” will appear largest.
# They occur 2 times each, so they have the highest frequency.
#
#
# ### 6. What is Named Entity Recognition (NER)?
# A.NER (Named Entity Recognition) is a technique used to identify names of people, places, organizations, dates, etc. in text.
# Example: “Himaja studies at KL University” → Himaja = Person, KL University = Organization.

# %% [markdown]
# ### In-Lab
#
# ### Activity 1: One-Hot Encoding
# Tasks
#  1. Import the required Python libraries.
#  2. Create a vocabulary from the given corpus.
#  3. Identify all unique words.
#  4. Generate One-Hot Encoding vectors for each unique word.
#  5. Display the One-Hot Encoding vectors in tabular format.

# %%
# ================================================================
# EXERCISE 3: TEXT REPRESENTATION TECHNIQUES
# ACTIVITY 1: ONE-HOT ENCODING
# ================================================================
#
# Tasks:
# 1. Import the required Python libraries.
# 2. Create a vocabulary from the given corpus.
# 3. Identify all unique words.
# 4. Generate One-Hot Encoding vectors for each unique word.
# 5. Display the One-Hot Encoding vectors in tabular format.
# ================================================================


# ------------------------------------------------
# TASK 1: Import Required Python Libraries
# ------------------------------------------------

import pandas as pd


# ------------------------------------------------
# TASK 2: Create the Given Text Corpus
# ------------------------------------------------

corpus = [
    "I love NLP",
    "I love Python",
    "NLP is fun"
]

documents = ["D1", "D2", "D3"]

print("Given Text Corpus:")
for doc, text in zip(documents, corpus):
    print(f"{doc}: {text}")


# ------------------------------------------------
# TASK 3: Create Vocabulary and Identify
#         All Unique Words
# ------------------------------------------------

# Convert all text to lowercase and split into words
tokens = []

for text in corpus:
    tokens.extend(text.lower().split())

# Identify unique words and arrange them alphabetically
vocabulary = sorted(set(tokens))

print("\nVocabulary:")
print(vocabulary)

print("\nVocabulary Size:")
print(len(vocabulary))


# ------------------------------------------------
# TASK 4: Generate One-Hot Encoding Vectors
#         for Each Unique Word
# ------------------------------------------------

one_hot_vectors = []

for word in vocabulary:

    # Create a vector containing zeros
    vector = [0] * len(vocabulary)

    # Find the position of the word in the vocabulary
    index = vocabulary.index(word)

    # Set the corresponding position to 1
    vector[index] = 1

    # Store the word and its vector
    one_hot_vectors.append([word] + vector)


# ------------------------------------------------
# TASK 5: Display One-Hot Encoding Vectors
#         in Tabular Format
# ------------------------------------------------

columns = ["Word"] + vocabulary

one_hot_df = pd.DataFrame(
    one_hot_vectors,
    columns=columns
)

print("\nOne-Hot Encoding Table:")
display(one_hot_df)
# Out:
# Given Text Corpus:
# D1: I love NLP
# D2: I love Python
# D3: NLP is fun
#
# Vocabulary:
# ['fun', 'i', 'is', 'love', 'nlp', 'python']
#
# Vocabulary Size:
# 6
#
# One-Hot Encoding Table:
#      Word  fun  i  is  love  nlp  python
# 0     fun    1  0   0     0    0       0
# 1       i    0  1   0     0    0       0
# 2      is    0  0   1     0    0       0
# 3    love    0  0   0     1    0       0
# 4     nlp    0  0   0     0    1       0
# 5  python    0  0   0     0    0       1

# %% [markdown]
# ### Activity 2: Bag of Words (BoW) Tasks
#
# 1. Create the Bag of Words model using CountVectorizer.
# 2. Generate the vocabulary.
# 3. Compute the frequency of each word in every document.
# 4. Construct the Document-Term Matrix (DTM).
# 5. Display the BoW matrix.

# %%
# ================================================================
# EXERCISE 3: TEXT REPRESENTATION TECHNIQUES
# ACTIVITY 2: BAG OF WORDS (BoW)
# ================================================================
#
# Tasks:
# 1. Create the Bag of Words model using CountVectorizer.
# 2. Generate the vocabulary.
# 3. Compute the frequency of each word in every document.
# 4. Construct the Document-Term Matrix (DTM).
# 5. Display the BoW matrix.
# ================================================================


# ------------------------------------------------
# TASK 1: Import Required Python Libraries
# ------------------------------------------------

import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer


# ------------------------------------------------
# Given Text Corpus
# ------------------------------------------------

corpus = [
    "I love NLP",
    "I love Python",
    "NLP is fun"
]

documents = ["D1", "D2", "D3"]

print("Given Text Corpus:")
for doc, text in zip(documents, corpus):
    print(f"{doc}: {text}")


# ------------------------------------------------
# TASK 1: Create the Bag of Words Model
# ------------------------------------------------

vectorizer = CountVectorizer()

# Fit the model and transform the corpus
bow_matrix = vectorizer.fit_transform(corpus)


# ------------------------------------------------
# TASK 2: Generate the Vocabulary
# ------------------------------------------------

vocabulary = vectorizer.get_feature_names_out()

print("\nVocabulary:")
print(list(vocabulary))

print("\nVocabulary Size:")
print(len(vocabulary))


# ------------------------------------------------
# TASK 3 & 4:
# Compute Word Frequencies and Construct
# the Document-Term Matrix (DTM)
# ------------------------------------------------

dtm = bow_matrix.toarray()

dtm_df = pd.DataFrame(
    dtm,
    index=documents,
    columns=vocabulary
)

print("\nDocument-Term Matrix (DTM):")
display(dtm_df)


# ------------------------------------------------
# TASK 5: Display the Bag of Words Matrix
# ------------------------------------------------

print("\nBag of Words (BoW) Matrix:")
display(dtm_df)


# ------------------------------------------------
# Display Word Frequencies for Each Document
# ------------------------------------------------

print("\nWord Frequencies in Each Document:")

for document, row in zip(documents, dtm):
    print(f"\n{document}:")
    
    for word, frequency in zip(vocabulary, row):
        if frequency > 0:
            print(f"  {word}: {frequency}")
# Out:
# Given Text Corpus:
# D1: I love NLP
# D2: I love Python
# D3: NLP is fun
#
# Vocabulary:
# ['fun', 'is', 'love', 'nlp', 'python']
#
# Vocabulary Size:
# 5
#
# Document-Term Matrix (DTM):
#     fun  is  love  nlp  python
# D1    0   0     1    1       0
# D2    0   0     1    0       1
# D3    1   1     0    1       0
# Bag of Words (BoW) Matrix:
#     fun  is  love  nlp  python
# D1    0   0     1    1       0
# D2    0   0     1    0       1
# D3    1   1     0    1       0
# Word Frequencies in Each Document:
#
# D1:
#   love: 1
#   nlp: 1
#
# D2:
#   love: 1
#   python: 1
#
# D3:
#   fun: 1
#   is: 1
#   nlp: 1

# %% [markdown]
# ### Activity 3: Word Cloud Tasks
# 1. Combine all documents into a single text.
# 2. Generate a Word Cloud.
# 3. Display the Word Cloud.
# 4. Identify the top five most frequent words from the visualization.

# %%
# !pip install wordcloud

# %%
# ================================================================
# EXERCISE 3: TEXT REPRESENTATION TECHNIQUES
# ACTIVITY 3: WORD CLOUD
# ================================================================
#
# Tasks:
# 1. Combine all documents into a single text.
# 2. Generate a Word Cloud.
# 3. Display the Word Cloud.
# 4. Identify the top five most frequent words.
# ================================================================


# ------------------------------------------------
# TASK 1: Import Required Libraries
# ------------------------------------------------

import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter


# ------------------------------------------------
# Given Text Corpus
# ------------------------------------------------

corpus = [
    "I love NLP",
    "I love Python",
    "NLP is fun"
]

documents = ["D1", "D2", "D3"]


# ------------------------------------------------
# TASK 1: Combine All Documents into One Text
# ------------------------------------------------

combined_text = " ".join(corpus).lower()

print("Combined Text:")
print(combined_text)


# ------------------------------------------------
# Calculate Word Frequencies
# ------------------------------------------------

words = combined_text.split()

word_frequency = Counter(words)

print("\nWord Frequencies:")
for word, frequency in word_frequency.items():
    print(f"{word}: {frequency}")


# ------------------------------------------------
# TASK 2: Generate the Word Cloud
# ------------------------------------------------

wordcloud = WordCloud(
    width=1200,
    height=600,
    background_color="white"
).generate_from_frequencies(word_frequency)


# ------------------------------------------------
# TASK 3: Display the Word Cloud
# ------------------------------------------------

plt.figure(figsize=(14, 7))

plt.imshow(wordcloud, interpolation="bilinear")

plt.axis("off")

plt.title(
    "Word Cloud - Text Corpus",
    fontsize=20,
    fontweight="bold"
)

plt.show()


# ------------------------------------------------
# TASK 4: Identify Top Five Most Frequent Words
# ------------------------------------------------

top_five_words = word_frequency.most_common(5)

print("\nTop Five Most Frequent Words:")
print("-" * 40)

for rank, (word, frequency) in enumerate(top_five_words, start=1):
    print(f"{rank}. {word} → {frequency}")
# Out:
# Combined Text:
# i love nlp i love python nlp is fun
#
# Word Frequencies:
# i: 2
# love: 2
# nlp: 2
# python: 1
# is: 1
# fun: 1
# Top Five Most Frequent Words:
# ----------------------------------------
# 1. i → 2
# 2. love → 2
# 3. nlp → 2
# 4. python → 1
# 5. is → 1

# %%
data =["Red", "Blue", "Green", "Red", "Blue"]

# %%
def one_hot_encode_manual(values):
    categories = sorted(set(values))    # unique categories, alphabetically ordered
    encoding = []
    for v in values:
        vector = [1 if v == cat else 0 for cat in categories]
        encoding.append(vector)
    return categories, encoding

categories, manual_encoded = one_hot_encode_manual(data)
print("=== Pure Python ===")
print("Categories:", categories)
for original, vector in zip(data, manual_encoded):
    print(f"{original:6s} -> {vector}")
print()
# Out:
# === Pure Python ===
# Categories: ['Blue', 'Green', 'Red']
# Red    -> [0, 0, 1]
# Blue   -> [1, 0, 0]
# Green  -> [0, 1, 0]
# Red    -> [0, 0, 1]
# Blue   -> [1, 0, 0]

# %%
import pandas as pd

df = pd.DataFrame({"Color":data})
pandas_encoded = pd.get_dummies(df["Color"], prefix="", prefix_sep="").astype(int)
print("=== pandas.get_dummies ===")
print(pandas_encoded.to_string(index=False))
print()
# Out:
# === pandas.get_dummies ===
#  Blue  Green  Red
#     0      0    1
#     1      0    0
#     0      1    0
#     0      0    1
#     1      0    0

# %%
from sklearn.preprocessing import OneHotEncoder
import numpy as np

encoder = OneHotEncoder(sparse_output=False)
sklearn_encoded = encoder.fit_transform(np.array(data).reshape(-1,1))
print("=== scikit-learn OneHotEncoder ===")
print("Categories:", encoder.categories_[0].tolist())
for original, vector in zip(data, sklearn_encoded):
    print(f"{original:6s} -> {vector.astype(int).tolist()}")
# Out:
# === scikit-learn OneHotEncoder ===
# Categories: ['Blue', 'Green', 'Red']
# Red    -> [0, 0, 1]
# Blue   -> [1, 0, 0]
# Green  -> [0, 1, 0]
# Red    -> [0, 0, 1]
# Blue   -> [1, 0, 0]

# %%
import math
A =[1,2,1]
B = [2,1,1]

# %%
import numpy as np

a_np = np.array(A)
b_np = np.array(B)
numpy_result = np.dot(a_np, b_np) / (np.linalg.norm(a_np) * np.linalg.norm(b_np))
print("=== Numpy ===")
print(f"cosine similarity = {numpy_result:.4f}")
print()
# Out:
# === Numpy ===
# cosine similarity = 0.8333

# %%
from sklearn.metrics.pairwise import cosine_similarity
sklearn_result = cosine.pariswise import  cosine_similarity
print("=== scikit
